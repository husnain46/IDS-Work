# %%
#import libraries
import folium
import pandas as pd

# %%
#create a map on Pakistan location
pakistan_map = folium.Map(location = [30.37,69.34],zoom_start=4.5,tiles='OpenStreetMap')

# %%
#import Google Drive and mount the entire drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load the dataset (csv file) into the Pandas dataframe
df = pd.read_csv('/content/drive/MyDrive/IDS DATASETS/Covid Dataset.csv')
df
# Out:
#              Cities  Latitude  Longitude  Recovery Toll  Death Toll  \
# 0            Lahore   31.5204    74.3587         214325        5076
# 1        Rawalpindi   33.5651    73.0169          36313        2046
# 2         Faislabad   31.4504    73.1350          24739        1274
# 3            Multan   30.1575    71.5249          21199         897
# 4          Sargodha   32.0740    72.6861          10539         364
# 5        Gujranwala   32.1877    74.1945           9504         611
# 6        Bahawalpur   29.3544    71.6911           9630         268
# 7           Sialkot   32.4945    74.5229           8354         247
# 8    Rahim Yar Khan   28.4212    70.2989           7729         290
# 9            Gujrat   32.5731    74.1005           7769         115
# 10  Dera Ghazi Khan   30.0489    70.6455           4829         204
# 11      Sheikhupura   31.7167    73.9850           4594         171
# 12          Sahiwal   30.6682    73.1114           4139         107
# 13   Toba Tek Singh   30.9709    72.4826           4085         137
# 14            Okara   30.8138    73.4534           3839          41
# 15            Jhang   31.2781    72.3317           3690          26
# 16           Vehari   30.0442    72.3441           3071          16
# 17     Muzaffargarh   30.0736    71.1805           2504         394
# 18         Mianwali   32.5839    71.5370           2719         137
# 19            Kasur   31.1179    74.4408           2839          18
# 20         Khanewal   30.2864    71.9320           2749           7
# 21           Jhelum   32.9425    73.7257           2689          58
# 22    Nankana Sahib   31.4492    73.7125           2704          23
# 23          Bhakkar   31.6082    71.0854           2604          52
# 24          Chiniot   31.7292    72.9822           2554          71
# 25          Khushab   32.2955    72.3489           2439          78
# 26        Pakpattan   30.3573    73.3827           2304          22
# 27        Hafizabad   32.0712    73.6895           2254          25
# 28  Mandi Bahauddin   32.5742    73.4828           2239          22
# 29     Bahawalnagar   30.0025    73.2412           2139          29
# 30           Layyah   30.9693    70.9428           2054          17
# 31          Chakwal   32.9328    72.8630           1754           5
# 32          Lodhran   29.5467    71.6276           1654          33
# 33           Attock   33.7660    72.3609           1504          35
# 34         Rajanpur   29.1044    70.3301           1324           7
# 35          Narowal   32.1014    74.8800           1054           3
#
#     Total Cases
# 0        222246
# 1         38527
# 2         26257
# 3         22313
# 4         11052
# 5         10238
# 6         10021
# 7          8742
# 8          8094
# 9          7978
# 10         5138
# 11         4915
# 12         4395
# 13         4369
# 14         4000
# 15         3739
# 16         3201
# 17         3049
# 18         2999
# 19         2969
# 20         2873
# 21         2855
# 22         2855
# 23         2782
# 24         2724
# 25         2581
# 26         2496
# 27         2374
# 28         2371
# 29         2279
# 30         2189
# 31         1869
# 32         1805
# 33         1637
# 34         1467
# 35         1099

# %%
#calculate total number of cases using a loop
t = 0
for c in df['Total Cases']:
  t = int(c)+int(t)

# %%
#mark circles on the map and displa the map
for city,lat,long,de,re,tc in zip(list(df['Cities']),list(df['Latitude']),list(df['Longitude']),list(df['Recovery Toll']),list(df['Death Toll']),list(df['Total Cases'])):
    folium.CircleMarker(location = [lat,long],
                       radius = (tc/t)*100,
                       color = 'red',
                       fill = False,
                       fill_color = 'blue').add_to(pakistan_map)
    xyz = '<strong>City:  ' + city + '</strong><br>' + 'Total Cases: ' + str(tc) + '<br>' + 'Deaths: '+ str(de) + '<br>' + 'Recoveries: ' + str(re) + '<br>'
    iframe = folium.IFrame(xyz, width=200, height=150)
    popupData = folium.Popup(iframe, max_width=500)
    folium.Marker(location = [lat,long], popup=popupData).add_to(pakistan_map)
    

pakistan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1ef408470c3e0b508c8d326e74f0af5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1ef408470c3e0b508c8d326e74f0af5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e1ef408470c3e0b508c8d326e74f0af5 = L.map(
#                 &quot;map_e1ef408470c3e0b508c8d326e74f0af5&quot;,
#                 {
#                     center: [30.37, 69.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3350e8093903c2d0df9e4c7a4480b98 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e1ef408470c3e0b508c8d326e74f0af5);
#
#
#             var circle_marker_5051dd91847ebd6cce41b61c3bf3b465 = L.circleMarker(
#                 [31.5204, 74.3587],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50.453350525995575, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1ef408470c3e0b508c8d326e74f0af5);
#
#
#             var marker_1d3dd7d835897b6df447d88403252fe1 = L.marker(
#                 [31.5204, 74.3587],
#                 {}
#             ).addTo(map_e1ef408470c3e0b508c8d326e74f0af5);
#
#
#         var popup_acf877edb10be70f26b1cb88d4e13cbf = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_ecffd217126ecada4eea16ac0875e8b4 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPlN0YXRlOiAgTGFob3JlPC9zdHJvbmc+PGJyPlRvdGFsIENhc2VzOiAyMjIyNDY8YnI+RGVhdGhzOiAyMTQzMjU8YnI+UmVjb3ZlcmllczogNTA3Njxicj4=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_acf877edb10be70f26b1cb88d4e13cbf.setContent(i_frame_ecffd217126ecada4eea16ac0875e8b4);
#
#
#         marker_1d3dd7d835897b6df447d88403252fe1.bindPopup(popup_acf877edb10be70f26b1cb88d4e13cbf)
#         ;
#
#
#
#
#             var circle_marker_bba2f49397df4907fbed3520efa761ce = L.circleMarker(
#                 [33.5651, 73.0169],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.746237213335815, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1ef408470c3e0b508c8d326e74f0af5);
#
#
#             var marker_42f7d3ab3d032bd012e9bf68780648f4 = L.marker(
#                 [33.5651, 73.0169],
#                 {}
#             ).addTo(map_e1ef408470c3e0b508c8d326e74f0af5);
#
#
#         var popup_a6dcffffad6002e42957b494a310090d = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_67e1229d8efd249a631627e23c4936e0 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPlN0YXRlOiAgUmF3YWxwaW5kaTwvc3Ryb25nPjxicj5Ub3RhbCBDYXNlczogMzg1Mjc8YnI+RGVhdGhzOiAzNjMxMzxicj5SZWNvdmVyaWVzOiAyMDQ2PGJyPg==&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_a6dcffffad6002e42957b494a310090d.setContent(i_frame_67e1229d8efd249a631627e23c4936e0);
#
#
#         marker_42f7d3ab3d032bd012e9bf68780648f4.bindPopup(popup_a6dcffffad6002e42957b494a310090d)
#         ;
#
#
#
#
#             var circle_marker_f1b785125740c277dc7647eaef51e007 = L.circleMarker(
#                 [31.4504, 73.135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.960753510799141, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1ef408470c3e0b508c8d326e74f0af5);
#
#
#             var marker_0c43cdbf6fc4da6f61d70631826e891d = L.marker(
#                 [31.4504, 73.135],
#                 {}
#             ).addTo(map_e1ef408470c3e0b508c8d326e74f0af5);
#
#
#         var popup_9de790af6288122c3d6b4e35f773c9b8 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_50034f65c7138a00fa80981955755338 = $(`&lt;iframe src=&q
